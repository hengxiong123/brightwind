# %%
<h1 style="text-align:center;font-size:36px;font-weight:bold;">How to export a tab file and save your data using the brightwind library</h1>

# %%
import datetime
print('Last updated: {}'.format(datetime.date.today().strftime('%d %B, %Y')))
# Out:
# Last updated: 15 October, 2024

# %% [markdown]
# <hr class="gray-line">
# <font size="6">Outline:</font>

# %% [markdown]
# This tutorial summarises how to use a number of functions in the brightwind library to load data. The following topics are included:
#
#     1.Importing the brightwind library
#     2.Loading .csv and .txt files with the load_csv() function
#     3.Loading multiple files with the load_csv() function
#     4.Ignoring additional header lines when using the load_csv() function
#     5.Loading Excel files with the load_excel() function
#     6.Loading Windographer text files with the load_windographer_txt() function
#     7.Loading Campbell Scientific data with the load_campbell_scientific() function
#     8.Some other considerations when using file paths

# %% [markdown]
# <hr class="gray-line">
# <font size="6">Data</font>

# %% [markdown]
# To follow along with this tutorial you can download the data from Dropbox here. Instead of using the file path C:\Users\Stephen\Documents\Analysis which is used in these tutorials you can replace it with the file path of the location where you downloaded the datasets to.

# %% [markdown]
# <hr class="gray-line">
# <font size="6">1. Importing the brightwind library</font>

# %% [markdown]
# The following command will import the brightwind python library assigning it to the tag ‘bw’. After this, ‘bw’ can be used to call specific functions within the library.

# %%
import brightwind as bw

# %% [markdown]
# <hr class="gray-line">
# <font size="6">2. Loading .csv and .txt files with the load_csv() function</font>

# %% [markdown]
# As mentioned above, we can now call the load_csv() of the brightwind library. First, we specify the name and directory of the input file. If you downloaded the datasets from Dropbox as outlined above, then replace this path with your own path to the data.

# %%
# specify location of existing sample dataset
data_file_path = r'E:\Programs\brightwind\brightwind\demo_datasets\demo_data.csv'

# %% [markdown]
# Then we can use the following command to load the data. The text to the left of the ‘=’ sign is the variable name that the data is assigned to. This can then be used to retrieve the data from memory.

# %%
# load data as dataframe
data = bw.load_csv(data_file_path)

# %% [markdown]
# The following command can then be used to view the first few rows of the loaded data.

# %%
# show first 5 rows of dataframe
data.head(5)
# Out:
#                      Spd80mN  Spd80mS  Spd60mN  Spd60mS  Spd40mN  Spd40mS
# Timestamp
# 2016-01-09 15:30:00    8.370    7.911    8.160    7.849    7.857    7.626  \
# 2016-01-09 15:40:00    8.250    7.961    8.100    7.884    7.952    7.840
# 2016-01-09 17:00:00    7.652    7.545    7.671    7.551    7.531    7.457
# 2016-01-09 17:10:00    7.382    7.325    6.818    6.689    6.252    6.174
# 2016-01-09 17:20:00    7.977    7.791    8.110    7.915    8.140    7.974
#
#                      Spd80mNStd  Spd80mSStd  Spd60mNStd  Spd60mSStd  ...
# Timestamp                                                            ...
# 2016-01-09 15:30:00       1.240       1.075       1.060       0.947  ...  \
# 2016-01-09 15:40:00       0.897       0.875       0.900       0.855  ...
# 2016-01-09 17:00:00       0.756       0.703       0.797       0.749  ...
# 2016-01-09 17:10:00       0.844       0.810       0.897       0.875  ...
# 2016-01-09 17:20:00       0.556       0.528       0.562       0.524  ...
#
#                      Dir78mSStd  Dir58mS  Dir58mSStd  Dir38mS  Dir38mSStd
# Timestamp
# 2016-01-09 15:30:00       6.100    110.1       6.009    112.2       5.724  \
# 2016-01-09 15:40:00       5.114    110.9       4.702    109.8       5.628
# 2016-01-09 17:00:00       4.172    113.1       3.447    111.8       4.016
# 2016-01-09 17:10:00       4.680    118.8       5.107    115.6       5.189
# 2016-01-09 17:20:00       3.123    115.9       2.960    113.6       3.540
#
#                        T2m   RH2m    P2m  PrcpTot  BattMin
# Timestamp
# 2016-01-09 15:30:00  0.711  100.0  935.0      0.0    12.94
# 2016-01-09 15:40:00  0.630  100.0  935.0      0.0    12.95
# 2016-01-09 17:00:00  1.126  100.0  934.0      0.0    12.75
# 2016-01-09 17:10:00  0.954  100.0  934.0      0.0    12.71
# 2016-01-09 17:20:00  0.863  100.0  934.0      0.0    12.69
#
# [5 rows x 29 columns]

# %% [markdown]
# The same approach can be used to load a comma separated ‘.txt’ file.

# %% [markdown]
# <hr class="gray-line">
# <font size="6">3. Loading multiple files with the load_csv() function</font>

# %% [markdown]
# The following method can be used to load a group of files all at once, such as a long record of data which is split into numerous daily files. In this case, we can simply refer to a folder containing all the files for upload and include the following extra arguments.

# %%
# specify location of folder with multiple files
folder = r'E:\Programs\brightwind\brightwind\demo_datasets\MERRA-2'
# load data as dataframe
data = bw.load_csv(folder, search_by_file_type=['.csv'], print_progress=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       2 folder = r'E:\Programs\brightwind\brightwind\demo_datasets\MERRA-2'
#       3 # load data as dataframe
# ----> 4 data = bw.load_csv(folder, search_by_file_type=['.csv'], print_progress=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\brightwind\load\load.py:156, in load_csv(filepath_or_folder, search_by_file_type, print_progress, dayfirst, **kwargs)
#     154     return _pandas_read_csv(filepath_or_folder, **merged_fn_args).tz_localize(None)
#     155 elif not is_file:
# --> 156     return _assemble_df_from_folder(filepath_or_folder, search_by_file_type, _pandas_read_csv, print_progress,
#     157                                     **merged_fn_args).tz_localize(None)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\brightwind\load\load.py:79, in _assemble_df_from_folder(source_folder, file_type, function_to_get_df, print_progress, **kwargs)
#      77 for file_name in files_list:
#      78     df = function_to_get_df(file_name, **kwargs)
# ---> 79     assembled_df = assembled_df.append(df, verify_integrity=True)
#      80     if print_progress:
#      81         print("{0} file read and appended".format(file_name))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# In the above case, ‘search_by_file_type’ is a list of file extensions to search for. This list can include multiple items, such as ['.csv', '.txt'].
#
# The ‘print_progress’ argument simply prints out a statement below the cell showing how many files have been processed.

# %% [markdown]
# <hr class="gray-line">
# <font size="6">4. Ignoring additional header lines when using the load_csv() function</font>

# %% [markdown]
# If the input file contains extra header lines (ie. the column headers are not contained in the first row), the ‘skiprows’ argument can be used to ignore these lines when loading the data.

# %%
# specify location of existing sample dataset, with 5 extra header rows
data_file_path = r'E:\Programs\brightwind\brightwind\demo_datasets\campbell_scientific_demo_data.csv'
# load data as dataframe
data = bw.load_csv(data_file_path, skiprows=5)
data.head()
# Out:
#                      1  demo_mast  7000   8.25  7.961    8.1  7.884  7.952
# 2016-01-09 15:40:00
# 2016-01-09 17:00:00  2  demo_mast  7000  7.652  7.545  7.671  7.551  7.531  \
# 2016-01-09 17:10:00  3  demo_mast  7000  7.382  7.325  6.818  6.689  6.252
# 2016-01-09 17:20:00  4  demo_mast  7000  7.977  7.791  8.110  7.915  8.140
# 2016-01-09 17:30:00  5  demo_mast  7000  8.340  8.160  8.370  8.170  8.330
# 2016-01-09 17:40:00  6  demo_mast  7000  8.130  7.929  8.090  7.895  7.972
#
#                       7.84  0.897  ...  5.114  110.9  4.702  109.8  5.628
# 2016-01-09 15:40:00                ...
# 2016-01-09 17:00:00  7.457  0.756  ...  4.172  113.1  3.447  111.8  4.016  \
# 2016-01-09 17:10:00  6.174  0.844  ...  4.680  118.8  5.107  115.6  5.189
# 2016-01-09 17:20:00  7.974  0.556  ...  3.123  115.9  2.960  113.6  3.540
# 2016-01-09 17:30:00  8.180  0.676  ...  3.260  117.2  3.600  117.4  4.526
# 2016-01-09 17:40:00  7.788  0.557  ...  3.677  115.9  3.371  115.9  3.515
#
#                       0.63    100    935    0  12.95
# 2016-01-09 15:40:00
# 2016-01-09 17:00:00  1.126  100.0  934.0  0.0  12.75
# 2016-01-09 17:10:00  0.954  100.0  934.0  0.0  12.71
# 2016-01-09 17:20:00  0.863  100.0  934.0  0.0  12.69
# 2016-01-09 17:30:00  0.731  100.0  934.0  0.0  12.67
# 2016-01-09 17:40:00  0.852  100.0  933.0  0.0  12.68
#
# [5 rows x 32 columns]

# %% [markdown]
# The load_csv() function is a wrapper around the widely used pandas.read_csv() function, and the argument ‘skiprows’ is one of many key word arguments (kwargs) which can be specified when using the function. Other key word arguments are described in the pandas.read_csv() documentation, which can be found at:
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html

# %% [markdown]
# <hr class="gray-line">
# <font size="6">5. Loading Excel files with the load_excel() function</font>

# %% [markdown]
# The load_excel() function offers similar functionality to load_csv() for Excel files. The following syntax can be used to load a single file. The function can be used to load both ‘.xls’ and ‘.xlsx’ files, provided the correct extension is specified with the filename.

# %%
# specify location of existing sample dataset, with 5 extra header rows
data_file_path = r'E:\Programs\brightwind\brightwind\demo_datasets\campbell_scientific_demo_data.xlsx'
# load data as dataframe
data = bw.load_excel(data_file_path)
data
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\brightwind\load\load.py:290: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.read_excel(filepath, **kwargs)
#                     some_site     CR1000     E7000  CR1000.Std.22
# TOA5
# Timestamp              RECORD       Site  LoggerID        Spd80mN  \
# TS                         RN        NaN       NaN  Metres/Second
# NaN                       NaN        Smp       Smp            Avg
# 2016-01-09 15:30:00         0  demo_mast      7000           8.37
# 2016-01-09 15:40:00         1  demo_mast      7000           8.25
# ...                       ...        ...       ...            ...
# 2017-11-23 10:10:00     95624  demo_mast      7000          10.48
# 2017-11-23 10:20:00     95625  demo_mast      7000           9.39
# 2017-11-23 10:30:00     95626  demo_mast      7000           9.14
# 2017-11-23 10:40:00     95627  demo_mast      7000          7.927
# 2017-11-23 10:50:00     95628  demo_mast      7000           7.12
#
#                     CPU:demo_mast.CR1          12345      demo_mast
# TOA5
# Timestamp                     Spd80mS        Spd60mN        Spd60mS  \
# TS                      Metres/Second  Metres/Second  Metres/Second
# NaN                               Avg            Avg            Avg
# 2016-01-09 15:30:00             7.911           8.16          7.849
# 2016-01-09 15:40:00             7.961            8.1          7.884
# ...                               ...            ...            ...
# 2017-11-23 10:10:00                 0          10.19           9.89
# 2017-11-23 10:20:00                 0           9.12           8.85
# 2017-11-23 10:30:00                 0            8.7           8.45
# 2017-11-23 10:40:00                 0          7.383          7.159
# 2017-11-23 10:50:00                 0          6.617          6.404
#
#                         Unnamed: 8     Unnamed: 9    Unnamed: 10  ...
# TOA5                                                              ...
# Timestamp                  Spd40mN        Spd40mS     Spd80mNStd  ...  \
# TS                   Metres/Second  Metres/Second  Metres/Second  ...
# NaN                            Avg            Avg            Std  ...
# 2016-01-09 15:30:00          7.857          7.626           1.24  ...
# 2016-01-09 15:40:00          7.952           7.84          0.897  ...
# ...                            ...            ...            ...  ...
# 2017-11-23 10:10:00           9.59           9.42           0.72  ...
# 2017-11-23 10:20:00           8.52           8.34          0.659  ...
# 2017-11-23 10:30:00           8.03          7.875          0.689  ...
# 2017-11-23 10:40:00          6.811          6.668          0.817  ...
# 2017-11-23 10:50:00          5.865          5.749          0.537  ...
#
#                     Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# TOA5
# Timestamp            Dir78mSStd     Dir58mS  Dir58mSStd     Dir38mS  \
# TS                          Deg         Deg         Deg         Deg
# NaN                         WVc         WVc         WVc         WVc
# 2016-01-09 15:30:00         6.1       110.1       6.009       112.2
# 2016-01-09 15:40:00       5.114       110.9       4.702       109.8
# ...                         ...         ...         ...         ...
# 2017-11-23 10:10:00           0       275.2           0       222.2
# 2017-11-23 10:20:00           0       275.2           0       218.4
# 2017-11-23 10:30:00           0       275.2           0         216
# 2017-11-23 10:40:00           0       275.2           0       219.5
# 2017-11-23 10:50:00           0       275.2           0       222.4
#
#                     Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30
# TOA5
# Timestamp            Dir38mSStd         T2m        RH2m         P2m  \
# TS                          Deg     Celcius           %   Millibars
# NaN                         WVc         Smp         Avg         Avg
# 2016-01-09 15:30:00       5.724       0.711         100         935
# 2016-01-09 15:40:00       5.628        0.63         100         935
# ...                         ...         ...         ...         ...
# 2017-11-23 10:10:00       4.111       0.943        99.7         943
# 2017-11-23 10:20:00       4.817       0.792        98.6         943
# 2017-11-23 10:30:00       5.784       0.802         100         943
# 2017-11-23 10:40:00       5.051       0.883         100         943
# 2017-11-23 10:50:00       4.902       0.802         100         944
#
#                     Unnamed: 31 Unnamed: 32
# TOA5
# Timestamp               PrcpTot     BattMin
# TS                           mm       Volts
# NaN                         Tot         Min
# 2016-01-09 15:30:00           0       12.94
# 2016-01-09 15:40:00           0       12.95
# ...                         ...         ...
# 2017-11-23 10:10:00           0       13.02
# 2017-11-23 10:20:00           0       13.69
# 2017-11-23 10:30:00           0       13.86
# 2017-11-23 10:40:00           0        13.8
# 2017-11-23 10:50:00           0       13.71
#
# [95632 rows x 32 columns]

# %% [markdown]
# The following command can be used to simultaneously load multiple files from a single folder.

# %%
# specify location of folder with multiple files
folder = r'E:\Programs\brightwind\brightwind\demo_datasets\campbell_scientific_demo_data0'
# load data as dataframe
data = bw.load_excel(folder, print_progress=True)
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\brightwind\load\load.py:290: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.read_excel(filepath, **kwargs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 4
#       2 folder = r'E:\Programs\brightwind\brightwind\demo_datasets\campbell_scientific_demo_data0'
#       3 # load data as dataframe
# ----> 4 data = bw.load_excel(folder, print_progress=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\brightwind\load\load.py:345, in load_excel(filepath_or_folder, search_by_file_type, print_progress, sheet_name, **kwargs)
#     343     return _pandas_read_excel(filepath_or_folder, **merged_fn_args)
#     344 elif not is_file:
# --> 345     return _assemble_df_from_folder(filepath_or_folder, search_by_file_type, _pandas_read_excel, print_progress,
#     346                                     **merged_fn_args)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\brightwind\load\load.py:79, in _assemble_df_from_folder(source_folder, file_type, function_to_get_df, print_progress, **kwargs)
#      77 for file_name in files_list:
#      78     df = function_to_get_df(file_name, **kwargs)
# ---> 79     assembled_df = assembled_df.append(df, verify_integrity=True)
#      80     if print_progress:
#      81         print("{0} file read and appended".format(file_name))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# Finally, the ‘skiprows’ key word argument can once again be used with load_excel() to ignore extra header lines within an input Excel file. load_excel() is again a wrapper around the pandas.read_excel() function, the full documentation of which is available at:
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html

# %%
# load data as dataframe
data = bw.load_excel(data_file_path, skiprows=5)
# Out:
#                          1  demo_mast  7000    8.25  7.961     8.1  7.884
# 2016-01-09 15:40:00
# 2016-01-09 17:00:00      2  demo_mast  7000   7.652  7.545   7.671  7.551  \
# 2016-01-09 17:10:00      3  demo_mast  7000   7.382  7.325   6.818  6.689
# 2016-01-09 17:20:00      4  demo_mast  7000   7.977  7.791   8.110  7.915
# 2016-01-09 17:30:00      5  demo_mast  7000   8.340  8.160   8.370  8.170
# 2016-01-09 17:40:00      6  demo_mast  7000   8.130  7.929   8.090  7.895
# ...                    ...        ...   ...     ...    ...     ...    ...
# 2017-11-23 10:10:00  95624  demo_mast  7000  10.480  0.000  10.190  9.890
# 2017-11-23 10:20:00  95625  demo_mast  7000   9.390  0.000   9.120  8.850
# 2017-11-23 10:30:00  95626  demo_mast  7000   9.140  0.000   8.700  8.450
# 2017-11-23 10:40:00  95627  demo_mast  7000   7.927  0.000   7.383  7.159
# 2017-11-23 10:50:00  95628  demo_mast  7000   7.120  0.000   6.617  6.404
#
#                      7.952   7.84  0.897  ...  5.114  110.9  4.702  109.8
# 2016-01-09 15:40:00                       ...
# 2016-01-09 17:00:00  7.531  7.457  0.756  ...  4.172  113.1  3.447  111.8  \
# 2016-01-09 17:10:00  6.252  6.174  0.844  ...  4.680  118.8  5.107  115.6
# 2016-01-09 17:20:00  8.140  7.974  0.556  ...  3.123  115.9  2.960  113.6
# 2016-01-09 17:30:00  8.330  8.180  0.676  ...  3.260  117.2  3.600  117.4
# 2016-01-09 17:40:00  7.972  7.788  0.557  ...  3.677  115.9  3.371  115.9
# ...                    ...    ...    ...  ...    ...    ...    ...    ...
# 2017-11-23 10:10:00  9.590  9.420  0.720  ...  0.000  275.2  0.000  222.2
# 2017-11-23 10:20:00  8.520  8.340  0.659  ...  0.000  275.2  0.000  218.4
# 2017-11-23 10:30:00  8.030  7.875  0.689  ...  0.000  275.2  0.000  216.0
# 2017-11-23 10:40:00  6.811  6.668  0.817  ...  0.000  275.2  0.000  219.5
# 2017-11-23 10:50:00  5.865  5.749  0.537  ...  0.000  275.2  0.000  222.4
#
#                      5.628   0.63    100    935    0  12.95
# 2016-01-09 15:40:00
# 2016-01-09 17:00:00  4.016  1.126  100.0  934.0  0.0  12.75
# 2016-01-09 17:10:00  5.189  0.954  100.0  934.0  0.0  12.71
# 2016-01-09 17:20:00  3.540  0.863  100.0  934.0  0.0  12.69
# 2016-01-09 17:30:00  4.526  0.731  100.0  934.0  0.0  12.67
# 2016-01-09 17:40:00  3.515  0.852  100.0  933.0  0.0  12.68
# ...                    ...    ...    ...    ...  ...    ...
# 2017-11-23 10:10:00  4.111  0.943   99.7  943.0  0.0  13.02
# 2017-11-23 10:20:00  4.817  0.792   98.6  943.0  0.0  13.69
# 2017-11-23 10:30:00  5.784  0.802  100.0  943.0  0.0  13.86
# 2017-11-23 10:40:00  5.051  0.883  100.0  943.0  0.0  13.80
# 2017-11-23 10:50:00  4.902  0.802  100.0  944.0  0.0  13.71
#
# [95627 rows x 32 columns]

# %% [markdown]
# <hr class="gray-line">
# <font size="6">6. Loading Windographer text files with the load_windographer_txt() function</font>

# %% [markdown]
# The load_windographer_txt() function can be used to load files which have been exported from Windographer.

# %% [markdown]
# <img src="E:\\Programs\\brightwind\\bw20241015\\Picture\\how_to_load_data_1.png" alt="图片描述" style="width:300px;height:200px;">

# %% [markdown]
# In this case, the following commands are used.

# %%
# specify location of existing sample dataset
windog_data_file_path = r'E:\Programs\brightwind\brightwind\demo_datasets\windographer_demo_data.txt'

# load data as dataframe
windog_data = bw.load_windographer_txt(windog_data_file_path)

# show first 5 rows of dataframe
windog_data.head(5)
# Out:
#                      Spd80mN  Spd80mS  Spd60mN  Spd60mS  Spd40mN  Spd40mS
# Date/Time
# 2016-01-09 15:30:00    8.370    7.911    8.160    7.849    7.857    7.626  \
# 2016-01-09 15:40:00    8.250    7.961    8.100    7.884    7.952    7.840
# 2016-01-09 17:00:00    7.652    7.545    7.671    7.551    7.531    7.457
# 2016-01-09 17:10:00    7.382    7.325    6.818    6.689    6.252    6.174
# 2016-01-09 17:20:00    7.977    7.791    8.110    7.915    8.140    7.974
#
#                      Spd80mNStd  Spd80mSStd  Spd60mNStd  Spd60mSStd  ...
# Date/Time                                                            ...
# 2016-01-09 15:30:00       1.240       1.075       1.060       0.947  ...  \
# 2016-01-09 15:40:00       0.897       0.875       0.900       0.855  ...
# 2016-01-09 17:00:00       0.756       0.703       0.797       0.749  ...
# 2016-01-09 17:10:00       0.844       0.810       0.897       0.875  ...
# 2016-01-09 17:20:00       0.556       0.528       0.562       0.524  ...
#
#                      Dir78mSStd  Dir58mS  Dir58mSStd  Dir38mS  Dir38mSStd
# Date/Time
# 2016-01-09 15:30:00       6.100    110.1       6.009    112.2       5.724  \
# 2016-01-09 15:40:00       5.114    110.9       4.702    109.8       5.628
# 2016-01-09 17:00:00       4.172    113.1       3.447    111.8       4.016
# 2016-01-09 17:10:00       4.680    118.8       5.107    115.6       5.189
# 2016-01-09 17:20:00       3.123    115.9       2.960    113.6       3.540
#
#                        T2m   RH2m    P2m  PrcpTot  BattMin
# Date/Time
# 2016-01-09 15:30:00  0.711  100.0  935.0      0.0    12.94
# 2016-01-09 15:40:00  0.630  100.0  935.0      0.0    12.95
# 2016-01-09 17:00:00  1.126  100.0  934.0      0.0    12.75
# 2016-01-09 17:10:00  0.954  100.0  934.0      0.0    12.71
# 2016-01-09 17:20:00  0.863  100.0  934.0      0.0    12.69
#
# [5 rows x 29 columns]

# %% [markdown]
# To load a Windographer file with a delimiter and flagged text which are different from the defaults, the following extra arguments can be used.

# %%
<hr class="gray-line">
<font size="6">Outline:</font>

# %%
<hr class="gray-line">
<font size="6">Outline:</font>

# %%
# # load data as dataframe
# windog_data = bw.load_windographer_txt(windog_data_file_path, delimiter=';', flag_text='***')

# %% [markdown]
# <hr class="gray-line">
# <font size="6">Loading Campbell Scientific data with the load_campbell_scientific() function</font>

# %% [markdown]
# The load_campbell_scientific() function can be used to load files created by Campbell Scientific loggers as follows.

# %%
# specify location of existing sample dataset
campbell_data_file_path = r'E:\Programs\brightwind\brightwind\demo_datasets\campbell_scientific_demo_data.csv'

# load data as dataframe
campbell_data = bw.load_campbell_scientific(campbell_data_file_path)

# show first few rows of dataframe
campbell_data.head(5)
# Out:
#                      RECORD       Site  LoggerID  Spd80mN  Spd80mS  Spd60mN
# Timestamp
# 2016-01-09 15:30:00       0  demo_mast      7000    8.370    7.911    8.160  \
# 2016-01-09 15:40:00       1  demo_mast      7000    8.250    7.961    8.100
# 2016-01-09 17:00:00       2  demo_mast      7000    7.652    7.545    7.671
# 2016-01-09 17:10:00       3  demo_mast      7000    7.382    7.325    6.818
# 2016-01-09 17:20:00       4  demo_mast      7000    7.977    7.791    8.110
#
#                      Spd60mS  Spd40mN  Spd40mS  Spd80mNStd  ...  Dir78mSStd
# Timestamp                                                   ...
# 2016-01-09 15:30:00    7.849    7.857    7.626       1.240  ...       6.100  \
# 2016-01-09 15:40:00    7.884    7.952    7.840       0.897  ...       5.114
# 2016-01-09 17:00:00    7.551    7.531    7.457       0.756  ...       4.172
# 2016-01-09 17:10:00    6.689    6.252    6.174       0.844  ...       4.680
# 2016-01-09 17:20:00    7.915    8.140    7.974       0.556  ...       3.123
#
#                      Dir58mS  Dir58mSStd  Dir38mS  Dir38mSStd    T2m   RH2m
# Timestamp
# 2016-01-09 15:30:00    110.1       6.009    112.2       5.724  0.711  100.0  \
# 2016-01-09 15:40:00    110.9       4.702    109.8       5.628  0.630  100.0
# 2016-01-09 17:00:00    113.1       3.447    111.8       4.016  1.126  100.0
# 2016-01-09 17:10:00    118.8       5.107    115.6       5.189  0.954  100.0
# 2016-01-09 17:20:00    115.9       2.960    113.6       3.540  0.863  100.0
#
#                        P2m  PrcpTot  BattMin
# Timestamp
# 2016-01-09 15:30:00  935.0      0.0    12.94
# 2016-01-09 15:40:00  935.0      0.0    12.95
# 2016-01-09 17:00:00  934.0      0.0    12.75
# 2016-01-09 17:10:00  934.0      0.0    12.71
# 2016-01-09 17:20:00  934.0      0.0    12.69
#
# [5 rows x 32 columns]

# %% [markdown]
# Finally, the same function can once again be used to load in a group of files from one folder using the following syntax.

# %%
# campbell_folder = r'E:\Programs\brightwind\brightwind\demo_datasets\campbell_scientific_demo_data0'
# campbell_data = bw.load_campbell_scientific(campbell_folder, print_progress=True)

# %% [markdown]
# <hr class="gray-line">
# <font size="6">8. Some other considerations when using file paths</font>

# %% [markdown]
# The local directory of the folder containing the demo datasets used in this tutorial and the following tutorials will depend on where you have download the brightwind library. An example directory has been included in the above examples in order to show how the functions are typically applied to local datasets. However these file paths will need to be updated in order to locate the demo datasets on your own computer.
#
# For ease of use, the following tutorials and doc strings within the library refer to demo datasets using the syntax shown below. This method allows Python to locate the demo data locally without the user making any updates.

# %% [markdown]
# bw.datasets.demo_data.csv
# bw.datasets.windographer_demo_data.txt
# bw.datasets...

# %% [markdown]
# You may have also noticed that the file paths used in the above sections include the prefix ‘r’. This is because the backslash, ‘\’, is a special character in Python and file paths which contain backslashes are not correctly interpretted by Python. Loading a csv file using a file path copied and pasted from Windows file explorer with backslashes will return the following error:

# %%
data_file_path = r'E:\Programs\brightwind\brightwind\demo_datasets\demo_data.csv'
data = bw.load_csv(data_file_path)

# %%
data.head()
# Out:
#                      Spd80mN  Spd80mS  Spd60mN  Spd60mS  Spd40mN  Spd40mS
# Timestamp
# 2016-01-09 15:30:00    8.370    7.911    8.160    7.849    7.857    7.626  \
# 2016-01-09 15:40:00    8.250    7.961    8.100    7.884    7.952    7.840
# 2016-01-09 17:00:00    7.652    7.545    7.671    7.551    7.531    7.457
# 2016-01-09 17:10:00    7.382    7.325    6.818    6.689    6.252    6.174
# 2016-01-09 17:20:00    7.977    7.791    8.110    7.915    8.140    7.974
#
#                      Spd80mNStd  Spd80mSStd  Spd60mNStd  Spd60mSStd  ...
# Timestamp                                                            ...
# 2016-01-09 15:30:00       1.240       1.075       1.060       0.947  ...  \
# 2016-01-09 15:40:00       0.897       0.875       0.900       0.855  ...
# 2016-01-09 17:00:00       0.756       0.703       0.797       0.749  ...
# 2016-01-09 17:10:00       0.844       0.810       0.897       0.875  ...
# 2016-01-09 17:20:00       0.556       0.528       0.562       0.524  ...
#
#                      Dir78mSStd  Dir58mS  Dir58mSStd  Dir38mS  Dir38mSStd
# Timestamp
# 2016-01-09 15:30:00       6.100    110.1       6.009    112.2       5.724  \
# 2016-01-09 15:40:00       5.114    110.9       4.702    109.8       5.628
# 2016-01-09 17:00:00       4.172    113.1       3.447    111.8       4.016
# 2016-01-09 17:10:00       4.680    118.8       5.107    115.6       5.189
# 2016-01-09 17:20:00       3.123    115.9       2.960    113.6       3.540
#
#                        T2m   RH2m    P2m  PrcpTot  BattMin
# Timestamp
# 2016-01-09 15:30:00  0.711  100.0  935.0      0.0    12.94
# 2016-01-09 15:40:00  0.630  100.0  935.0      0.0    12.95
# 2016-01-09 17:00:00  1.126  100.0  934.0      0.0    12.75
# 2016-01-09 17:10:00  0.954  100.0  934.0      0.0    12.71
# 2016-01-09 17:20:00  0.863  100.0  934.0      0.0    12.69
#
# [5 rows x 29 columns]

# %% [markdown]
# The solution to this problem is to include a prefix, ‘r’ which allows backslashes in the filepath to be correctly interpreted by Python and the intended file to be found.

# %%
<hr class="gray-line">
<font size="6">6. Loading Windographer text files with the load_windographer_txt() function</font>
